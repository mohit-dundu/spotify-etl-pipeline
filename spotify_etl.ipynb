# %%
# !pip install spotipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 2.9 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="b6ffc538ed0840f6ab8150fa4fb47b0b",client_secret="436e3ea513954d58bf15e4b234fa8927")

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbLp5XoPON0wI"

# %%
playlist_uri = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
print(data)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbLp5XoPON0wI/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2023-11-03T08:47:41Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'}, 'href': 'https://api.spotify.com/v1/users/', 'id': '', 'type': 'user', 'uri': 'spotify:user:'}, 'is_local': False, 'primary_color': None, 'track': {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'}, 'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02', 'id': '06HL4z0CvFAxyc27GXpf02', 'name': 'Taylor Swift', 'type': 'artist', 'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH'
# ...

# %%
len(data['items'])
# Out:
# 7

# %%
data['items'][0]['track']['album']['id']
# Out:
# '64LU4c1nfjz1t4VnGhagcg'

# %%
data['items'][0]['track']['album']['name']
# Out:
# "1989 (Taylor's Version)"

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-10-26'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 21

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'

# %%
album_list = []
for row in data['items']:
  album_id = row['track']['album']['id']
  album_name = row['track']['album']['name']
  album_release_date = row['track']['album']['release_date']
  album_total_tracks = row['track']['album']['total_tracks']
  album_url = row['track']['album']['external_urls']['spotify']
  album_element = {'album_id':album_id,'name':album_name,
                   'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
  album_list.append(album_element)
print(album_list)
# Out:
# [{'album_id': '64LU4c1nfjz1t4VnGhagcg', 'name': "1989 (Taylor's Version)", 'release_date': '2023-10-26', 'total_tracks': 21, 'url': 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'}, {'album_id': '64LU4c1nfjz1t4VnGhagcg', 'name': "1989 (Taylor's Version)", 'release_date': '2023-10-26', 'total_tracks': 21, 'url': 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'}, {'album_id': '64LU4c1nfjz1t4VnGhagcg', 'name': "1989 (Taylor's Version)", 'release_date': '2023-10-26', 'total_tracks': 21, 'url': 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'}, {'album_id': '64LU4c1nfjz1t4VnGhagcg', 'name': "1989 (Taylor's Version)", 'release_date': '2023-10-26', 'total_tracks': 21, 'url': 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'}, {'album_id': '64LU4c1nfjz1t4VnGhagcg', 'name': "1989 (Taylor's Version)", 'release_date': '2023-10-26', 'total_tracks': 21, 'url': 'https://open.spotify.com/album/64LU4c1nfjz1t4VnGhagcg'}, {'album_id': '64LU4c1nfjz1t4VnGhagcg', 'name': "1989
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-11-03T08:47:41Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                     name release_date  total_tracks  \
# 0  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)   2023-10-26            21
# 1  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)   2023-10-26            21
# 2  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)   2023-10-26            21
# 3  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)   2023-10-26            21
# 4  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)   2023-10-26            21
#
#                                                  url
# 0  https://open.spotify.com/album/64LU4c1nfjz1t4V...
# 1  https://open.spotify.com/album/64LU4c1nfjz1t4V...
# 2  https://open.spotify.com/album/64LU4c1nfjz1t4V...
# 3  https://open.spotify.com/album/64LU4c1nfjz1t4V...
# 4  https://open.spotify.com/album/64LU4c1nfjz1t4V...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  1Iq8oo9XkmmvCQiGOfORiz  Is It Over Now? (Taylor's Version) (From The V...
# 1  5KD6AEm19QnMbfWpfoOHMl  Now That We Don't Talk (Taylor's Version) (Fro...
# 2  71BqAINEnezjQfxE4VuJfq        "Slut!" (Taylor's Version) (From The Vault)
# 3  4NioO5R9sHEZh4cGzMHyNt   Say Don't Go (Taylor's Version) (From The Vault)
# 4  6T0sEnqjmHISIKwFETeeiP  Suburban Legends (Taylor's Version) (From The ...
#
#    duration_ms                                                url  popularity  \
# 0       229477  https://open.spotify.com/track/1Iq8oo9XkmmvCQi...          92
# 1       146436  https://open.spotify.com/track/5KD6AEm19QnMbfW...          91
# 2       180381  https://open.spotify.com/track/71BqAINEnezjQfx...          91
# 3       279833  https://open.spotify.com/track/4NioO5R9sHEZh4c...          90
# 4       171818  https://open.spotify.com/track/6T0sEnqjmHISIKw...          88
#
# ...

# %%
artist_df.head()
# Out:
#                  artist_id   artist_name  \
# 0   06HL4z0CvFAxyc27GXpf02  Taylor Swift
# 12  3TVXtAsR1Inumwj472S9r4         Drake
# 13  3qiHUAX7zY4Qnjx8TNUzVx          Yeat
# 21  5cj0lLjcoR7YOSnhnX0Po5      Doja Cat
# 22  2uYWxilOVlUdk4oV9DvwqK        Mitski
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 12  https://api.spotify.com/v1/artists/3TVXtAsR1In...
# 13  https://api.spotify.com/v1/artists/3qiHUAX7zY4...
# 21  https://api.spotify.com/v1/artists/5cj0lLjcoR7...
# 22  https://api.spotify.com/v1/artists/2uYWxilOVlU...

# %%
album_df.head()
# Out:
#                   album_id                                    name  \
# 0   64LU4c1nfjz1t4VnGhagcg                 1989 (Taylor's Version)
# 12  4czdORdCWP9umpbhFXK2fW                        For All The Dogs
# 20  1bBez9PNvkJPW08bU7NYta                                 Scarlet
# 21  2Cn1d2KgbkAqbZCJ1RzdkA  The Land Is Inhospitable and So Are We
# 23  6PbnGueEO6LGodPfvNldYf                              Zach Bryan
#
#    release_date  total_tracks  \
# 0    2023-10-26            21
# 12   2023-10-06            23
# 20   2023-09-20            15
# 21   2023-09-15            11
# 23   2023-08-25            16
#
#                                                   url
# 0   https://open.spotify.com/album/64LU4c1nfjz1t4V...
# 12  https://open.spotify.com/album/4czdORdCWP9umpb...
# 20  https://open.spotify.com/album/1bBez9PNvkJPW08...
# 21  https://open.spotify.com/album/2Cn1d2KgbkAqbZC...
# 23  https://open.spotify.com/album/6PbnGueEO6LGodP...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
